# %%
import pandas as pd
import numpy as np

# %%
d = {'col1': ['a','b'], 'col2': [3, 4],'col3':['A','B']}

# %%
data = pd.DataFrame(data=d)

# %%
data.to_csv("test.csv")

# %%
data.to_csv("test_t.csv",sep='\t')

# %%
data
# Out:
#   col1  col2 col3
# 0    a     3    A
# 1    b     4    B

# %%
t3a.ix[day_values==test_day,:].to_csv(open(fn_v, 'w'), sep='\t', header=False, index=False)

# %%
data.col1 = data.col1.map(lambda x:'1:'+x).values

# %%
data
# Out:
#   col1  col2 col3
# 0  1:a     3    A
# 1  1:b     4    B

# %%
data.to_csv("test.csv",sep='\t')

# %%
reader = pd.read_csv("train/train.csv",iterator=True)
t0org = reader.get_chunk(500000)

# %% [markdown]
# # 训练与测试合并

# %%
h0org['click'] = 0#test和train链接在一起
t0org = pd.concat([t0org0, h0org])

# %% [markdown]
# # basic feature

# %%
t0org['day']=np.round(t0org.hour % 10000 / 100)#日期
t0org['hour1'] = np.round(t0org.hour % 100)#hour时
t0org['day_hour'] = (t0org.day.values - 21) * 24 + t0org.hour1.values#距离21号0时的时间数
t0org['day_hour_prev'] = t0org['day_hour'] - 1#前一小时
t0org['day_hour_next'] = t0org['day_hour'] + 1#后一小时
t0org['app_or_web'] = 0
t0org.ix[t0org.app_id.values=='ecad2386', 'app_or_web'] = 1

t0 = t0org

t0['app_site_id'] = np.add(t0.app_id.values, t0.site_id.values)
# Out:
# C:\Users\shachuanyu\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   import sys

# %% [markdown]
# # to encode categorical features using mean responses from earlier days -- univariate

# %% [markdown]
# # to count prev/current/next hour by ip ...

# %%
df=t0
vn= 'device_ip'
key_src='day_hour'
key_tgt='day_hour_prev'

# %%
_key_src = np.add(df[key_src].astype('str').values, df[vn].astype('str').values)
_key_tgt = np.add(df[key_tgt].astype('str').values, df[vn].astype('str').values)

# %%
grp1 = df.groupby(_key_src)
cnt1 = grp1[vn].aggregate(np.size)

# %%
_cnt = cnt1[_key_tgt].values

# %%
cnt1[_key_tgt]
# Out:
# -1.0ddd2926e      NaN
# -1.096809ac8      NaN
# -1.0b3cf8def      NaN
# -1.0e8275b8f      NaN
# -1.09644d0bf      NaN
# -1.005241af0      NaN
# -1.0b264c159      NaN
# -1.0e6f67278      NaN
# -1.037e8da74      NaN
# -1.0f1ac7184      NaN
# -1.05d877109      NaN
# -1.06f407810      NaN
# -1.058811cdf      NaN
# -1.072aab6df      NaN
# -1.06dec2796      NaN
# -1.0a4f47b2e      NaN
# -1.09b1fe278      NaN
# -1.0c26c53cf      NaN
# -1.0b7a69808      NaN
# -1.0fa60af6b      NaN
# -1.08a308c73      NaN
# -1.01b6530bc      NaN
# -1.0a2d12b33      NaN
# -1.0c6563308      NaN
# -1.0e99d0c2e      NaN
# -1.069890c7f      NaN
# -1.0c62f7206      NaN
# -1.02a2bfc89      NaN
# -1.050d86760      NaN
# -1.0431b3174      NaN
#                 ...
# 2.080306e90       NaN
# 2.097d75693       9.0
# 2.0ee0f3ff6       NaN
# 2.0ff1ecab0       NaN
# 2.007e63fe1       NaN
# 2.024b7f0e6       NaN
# 2.01cf29716     484.0
# 2.0fe1972dd       NaN
# 2.0ab38c26a       NaN
# 2.00c0635a2      78.0
# ...

# %% [markdown]
# # to create day diffs

# %%
t0['pday'] = t0.day - 1
df=t0
vn='device_ip'
key_src='day'
key_tgt='pday'
vn_y='click'
cred_k=10
_key_src = np.add(df[key_src].astype('str').values, df[vn].astype('str').values)
_key_tgt = np.add(df[key_tgt].astype('str').values, df[vn].astype('str').values)
grp1 = df.groupby(_key_src)
sum1 = grp1[vn_y].aggregate(np.sum)
cnt1 = grp1[vn_y].aggregate(np.size)

# %%
sum1
# Out:
# 21.000001c3b    2
# 21.000009aad    0
# 21.00000bfc0    0
# 21.00000c448    0
# 21.00000c90e    1
# 21.00001095d    0
# 21.000011a60    1
# 21.00001488a    0
# 21.000014c42    2
# 21.000017d37    0
# 21.000018aa7    0
# 21.00001e083    0
# 21.00002133a    1
# 21.00002b40a    0
# 21.00002e212    0
# 21.00002f7e4    0
# 21.00003a4fa    0
# 21.00003ba91    0
# 21.000051d30    0
# 21.000053efb    0
# 21.0000556c1    0
# 21.00005c284    0
# 21.00005cd34    0
# 21.000061507    1
# 21.000064509    0
# 21.0000700cd    0
# 21.000073f28    0
# 21.00007786f    0
# 21.000086300    0
# 21.000099deb    0
#                ..
# 21.0fff5e653    0
# 21.0fff5e874    0
# 21.0fff63db3    1
# 21.0fff65f28    0
# 21.0fff66839    6
# 21.0fff681f0    0
# 21.0fff6e255    1
# 21.0fff71c98    0
# 21.0fff81b9e    0
# 21.0fff81f4b    0
# 21.0fff82817    1
# 21.0fff84cb1    0
# 21.0fff91977    0
# 21.0fff9d9bd    0
# 21.0fffa9147    1
# 21.0fffb099d    1
# 21.0fffbb7e7    0
# 21.0fffc40f7    0
# 21.0fffc6570    0
# ...

# %%
cnt1
# Out:
# 21.000001c3b     2
# 21.000009aad     1
# 21.00000bfc0     2
# 21.00000c448     1
# 21.00000c90e     1
# 21.00001095d     6
# 21.000011a60     1
# 21.00001488a     1
# 21.000014c42     4
# 21.000017d37     1
# 21.000018aa7     2
# 21.00001e083     1
# 21.00002133a     5
# 21.00002b40a     3
# 21.00002e212     1
# 21.00002f7e4     2
# 21.00003a4fa     1
# 21.00003ba91     1
# 21.000051d30     1
# 21.000053efb     1
# 21.0000556c1     1
# 21.00005c284     1
# 21.00005cd34     2
# 21.000061507     1
# 21.000064509     1
# 21.0000700cd     3
# 21.000073f28     2
# 21.00007786f    11
# 21.000086300     1
# 21.000099deb     1
#                 ..
# 21.0fff5e653     1
# 21.0fff5e874     5
# 21.0fff63db3     6
# 21.0fff65f28     1
# 21.0fff66839    38
# 21.0fff681f0     1
# 21.0fff6e255     1
# 21.0fff71c98     3
# 21.0fff81b9e     1
# 21.0fff81f4b     4
# 21.0fff82817     1
# 21.0fff84cb1     1
# 21.0fff91977     1
# 21.0fff9d9bd     1
# 21.0fffa9147     1
# 21.0fffb099d     2
# ...

# %%
cnt1[_key_tgt]
# Out:
# 20.0ddd2926e   NaN
# 20.096809ac8   NaN
# 20.0b3cf8def   NaN
# 20.0e8275b8f   NaN
# 20.09644d0bf   NaN
# 20.005241af0   NaN
# 20.0b264c159   NaN
# 20.0e6f67278   NaN
# 20.037e8da74   NaN
# 20.0f1ac7184   NaN
# 20.05d877109   NaN
# 20.06f407810   NaN
# 20.058811cdf   NaN
# 20.072aab6df   NaN
# 20.06dec2796   NaN
# 20.0a4f47b2e   NaN
# 20.09b1fe278   NaN
# 20.0c26c53cf   NaN
# 20.0b7a69808   NaN
# 20.0fa60af6b   NaN
# 20.08a308c73   NaN
# 20.01b6530bc   NaN
# 20.0a2d12b33   NaN
# 20.0c6563308   NaN
# 20.0e99d0c2e   NaN
# 20.069890c7f   NaN
# 20.0c62f7206   NaN
# 20.02a2bfc89   NaN
# 20.050d86760   NaN
# 20.0431b3174   NaN
#                 ..
# 20.080306e90   NaN
# 20.097d75693   NaN
# 20.0ee0f3ff6   NaN
# 20.0ff1ecab0   NaN
# 20.007e63fe1   NaN
# 20.024b7f0e6   NaN
# 20.01cf29716   NaN
# 20.0fe1972dd   NaN
# 20.0ab38c26a   NaN
# 20.00c0635a2   NaN
# 20.028e52c03   NaN
# 20.0eb82bf3b   NaN
# 20.04a040c6a   NaN
# 20.050aa7e41   NaN
# 20.0209e2a76   NaN
# 20.002c1c53f   NaN
# ...

# %%
grp2 = df.groupby(_key_tgt)

# %%
cnt2 = grp2[vn_y].aggregate(np.size)

# %%
cnt2
# Out:
# 20.000001c3b     2
# 20.000009aad     1
# 20.00000bfc0     2
# 20.00000c448     1
# 20.00000c90e     1
# 20.00001095d     6
# 20.000011a60     1
# 20.00001488a     1
# 20.000014c42     4
# 20.000017d37     1
# 20.000018aa7     2
# 20.00001e083     1
# 20.00002133a     5
# 20.00002b40a     3
# 20.00002e212     1
# 20.00002f7e4     2
# 20.00003a4fa     1
# 20.00003ba91     1
# 20.000051d30     1
# 20.000053efb     1
# 20.0000556c1     1
# 20.00005c284     1
# 20.00005cd34     2
# 20.000061507     1
# 20.000064509     1
# 20.0000700cd     3
# 20.000073f28     2
# 20.00007786f    11
# 20.000086300     1
# 20.000099deb     1
#                 ..
# 20.0fff5e653     1
# 20.0fff5e874     5
# 20.0fff63db3     6
# 20.0fff65f28     1
# 20.0fff66839    38
# 20.0fff681f0     1
# 20.0fff6e255     1
# 20.0fff71c98     3
# 20.0fff81b9e     1
# 20.0fff81f4b     4
# 20.0fff82817     1
# 20.0fff84cb1     1
# 20.0fff91977     1
# 20.0fff9d9bd     1
# 20.0fffa9147     1
# 20.0fffb099d     2
# ...

# %%
grp3=df.groupby(_key_src)
cnt3 = grp3[vn_y].aggregate(np.size)

# %%
cnt2[_key_tgt]
# Out:
# 20.0ddd2926e    1412
# 20.096809ac8       7
# 20.0b3cf8def       2
# 20.0e8275b8f       2
# 20.09644d0bf      31
# 20.005241af0       3
# 20.0b264c159      19
# 20.0e6f67278       5
# 20.037e8da74       1
# 20.0f1ac7184       1
# 20.05d877109       2
# 20.06f407810       7
# 20.058811cdf       1
# 20.072aab6df       5
# 20.06dec2796      10
# 20.0a4f47b2e       1
# 20.09b1fe278    1338
# 20.0c26c53cf       8
# 20.0b7a69808       5
# 20.0fa60af6b       1
# 20.08a308c73      46
# 20.01b6530bc      29
# 20.0a2d12b33      46
# 20.0c6563308    1356
# 20.0e99d0c2e      10
# 20.069890c7f       8
# 20.0c62f7206       8
# 20.02a2bfc89       1
# 20.050d86760     192
# 20.0431b3174    1663
#                 ...
# 20.080306e90       1
# 20.097d75693      14
# 20.0ee0f3ff6       1
# 20.0ff1ecab0       1
# 20.007e63fe1       2
# 20.024b7f0e6       1
# 20.01cf29716    1404
# 20.0fe1972dd       1
# 20.0ab38c26a      18
# 20.00c0635a2     126
# 20.028e52c03       1
# 20.0eb82bf3b      21
# ...

# %%
cnt3[_key_src]
# Out:
# 21.0ddd2926e    1412
# 21.096809ac8       7
# 21.0b3cf8def       2
# 21.0e8275b8f       2
# 21.09644d0bf      31
# 21.005241af0       3
# 21.0b264c159      19
# 21.0e6f67278       5
# 21.037e8da74       1
# 21.0f1ac7184       1
# 21.05d877109       2
# 21.06f407810       7
# 21.058811cdf       1
# 21.072aab6df       5
# 21.06dec2796      10
# 21.0a4f47b2e       1
# 21.09b1fe278    1338
# 21.0c26c53cf       8
# 21.0b7a69808       5
# 21.0fa60af6b       1
# 21.08a308c73      46
# 21.01b6530bc      29
# 21.0a2d12b33      46
# 21.0c6563308    1356
# 21.0e99d0c2e      10
# 21.069890c7f       8
# 21.0c62f7206       8
# 21.02a2bfc89       1
# 21.050d86760     192
# 21.0431b3174    1663
#                 ...
# 21.080306e90       1
# 21.097d75693      14
# 21.0ee0f3ff6       1
# 21.0ff1ecab0       1
# 21.007e63fe1       2
# 21.024b7f0e6       1
# 21.01cf29716    1404
# 21.0fe1972dd       1
# 21.0ab38c26a      18
# 21.00c0635a2     126
# 21.028e52c03       1
# 21.0eb82bf3b      21
# ...

# %%
group_by=t0.device_ip.values.astype('str')
count_by=t0.app_id.values.astype('str')

# %%
group_by
# Out:
# array(['ddd2926e', '96809ac8', 'b3cf8def', ..., '396a38a8', 'fa7a267e',
#        'f1a323ab'], dtype='<U8')

# %%
_ord = np.lexsort((count_by, group_by))

# %%
_ones = pd.Series(np.ones(group_by.size))

# %%
_cs1 = np.zeros(group_by.size)

# %%
runnting_cnt = 0

# %%
org_idx = np.zeros(group_by.size, dtype=np.int)

# %%
org_idx[_ord]=np.asarray(range(group_by.size))

# %%
np.asarray(range(group_by.size))
# Out:
# array([     0,      1,      2, ..., 499997, 499998, 499999])

# %%
org_idx
# Out:
# array([433269, 294265, 353199, ..., 108379, 489264, 472681])

# %%
_ord
# Out:
# array([138515, 206603, 421703, ...,  46054, 115428, 125803], dtype=int64)

# %%
org_idx[_ord]
# Out:
# array([     0,      1,      2, ..., 499997, 499998, 499999])

# %%
a= np.zeros(10)

# %%
a[[2,5,1,7]]=np.arange(4)#0,1,2,3

# %%
a
# Out:
# array([0., 2., 0., 0., 0., 1., 0., 3., 0., 0.])

# %%
value=t0.id
group_by=t0.device_ip.values
g1=pd.Series(value).groupby(group_by)

# %%
agg1 = g1.aggregate(np.size)

# %%
# Out:
#                   id  click      hour    C1  banner_pos   site_id site_domain  \
# 0       1.000009e+18      0  14102100  1005           0  1fbe01fe    f3845767
# 1       1.000017e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 2       1.000037e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 3       1.000064e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 4       1.000068e+19      0  14102100  1005           1  fe8cc448    9166c161
# 5       1.000072e+19      0  14102100  1005           0  d6137915    bb1ef334
# 6       1.000072e+19      0  14102100  1005           0  8fda644b    25d4cfcd
# 7       1.000092e+19      0  14102100  1005           1  e151e245    7e091613
# 8       1.000095e+19      1  14102100  1005           0  1fbe01fe    f3845767
# 9       1.000126e+19      0  14102100  1002           0  84c7ba46    c4e18dd6
# 10      1.000187e+19      0  14102100  1005           1  e151e245    7e091613
# ...

# %%
g2 = t0[['click','device_ip']].groupby(a)

# %%
a = pd.Series([1,1,1,3,3,3,2,2,2])
a
# Out:
# 0    1
# 1    1
# 2    1
# 3    3
# 4    3
# 5    3
# 6    2
# 7    2
# 8    2
# dtype: int64

# %%
agg2 = g2.aggregate(np.size)

# %%
a
# Out:
# array(['ddd2926e', '96809ac8', 'b3cf8def', ..., '396a38a8', 'fa7a267e',
#        'f1a323ab'], dtype=object)

# %%
agg2
# Out:
#      click  device_ip
# 1.0      3          3
# 2.0      3          3
# 3.0      3          3

# %%
agg1
# Out:
# 00001c3b     2.0
# 00009aad     1.0
# 0000bfc0     2.0
# 0000c448     1.0
# 0000c90e     1.0
# 0001095d     6.0
# 00011a60     1.0
# 0001488a     1.0
# 00014c42     4.0
# 00017d37     1.0
# 00018aa7     2.0
# 0001e083     1.0
# 0002133a     5.0
# 0002b40a     3.0
# 0002e212     1.0
# 0002f7e4     2.0
# 0003a4fa     1.0
# 0003ba91     1.0
# 00051d30     1.0
# 00053efb     1.0
# 000556c1     1.0
# 0005c284     1.0
# 0005cd34     2.0
# 00061507     1.0
# 00064509     1.0
# 000700cd     3.0
# 00073f28     2.0
# 0007786f    11.0
# 00086300     1.0
# 00099deb     1.0
#             ...
# fff5e653     1.0
# fff5e874     5.0
# fff63db3     6.0
# fff65f28     1.0
# fff66839    38.0
# fff681f0     1.0
# fff6e255     1.0
# fff71c98     3.0
# fff81b9e     1.0
# fff81f4b     4.0
# fff82817     1.0
# fff84cb1     1.0
# fff91977     1.0
# fff9d9bd     1.0
# fffa9147     1.0
# fffb099d     2.0
# fffbb7e7     1.0
# fffc40f7     1.0
# fffc6570     1.0
# fffc729b     1.0
# fffce275     1.0
# ...

# %%
a = pd.Series([1,1,1,3,3,3,2,2,2])

# %%
a
# Out:
# 0    1
# 1    1
# 2    1
# 3    3
# 4    3
# 5    3
# 6    2
# 7    2
# 8    2
# dtype: int64

# %%
g2=t0.groupby(a)

# %%
g2['click'].aggregate(np.size)
# Out:
# 1.0    3
# 2.0    3
# 3.0    3
# Name: click, dtype: int64

# %%
agg1  = g1.aggregate(np.size)

# %%
g3 =t0.groupby(group_by)
agg3 = g3.aggregate(np.size)

# %%
agg3
# Out:
#             id  click  hour  C1  banner_pos  site_id  site_domain  \
# 00001c3b   2.0      2     2   2           2        2            2
# 00009aad   1.0      1     1   1           1        1            1
# 0000bfc0   2.0      2     2   2           2        2            2
# 0000c448   1.0      1     1   1           1        1            1
# 0000c90e   1.0      1     1   1           1        1            1
# 0001095d   6.0      6     6   6           6        6            6
# 00011a60   1.0      1     1   1           1        1            1
# 0001488a   1.0      1     1   1           1        1            1
# 00014c42   4.0      4     4   4           4        4            4
# 00017d37   1.0      1     1   1           1        1            1
# 00018aa7   2.0      2     2   2           2        2            2
# 0001e083   1.0      1     1   1           1        1            1
# 0002133a   5.0      5     5   5           5        5            5
# ...

# %%
pd.Series(value)
# Out:
# 0         1.000009e+18
# 1         1.000017e+19
# 2         1.000037e+19
# 3         1.000064e+19
# 4         1.000068e+19
# 5         1.000072e+19
# 6         1.000072e+19
# 7         1.000092e+19
# 8         1.000095e+19
# 9         1.000126e+19
# 10        1.000187e+19
# 11        1.000197e+19
# 12        1.000203e+19
# 13        1.000204e+19
# 14        1.000252e+19
# 15        1.000354e+19
# 16        1.000359e+19
# 17        1.000411e+19
# 18        1.000418e+19
# 19        1.000448e+19
# 20        1.000451e+19
# 21        1.000457e+19
# 22        1.000467e+19
# 23        1.000477e+19
# 24        1.000525e+19
# 25        1.000533e+19
# 26        1.000554e+19
# 27        1.000561e+19
# 28        1.000565e+19
# 29        1.000595e+19
#               ...
# 499970    1.311004e+19
# 499971    1.311004e+19
# 499972    1.311014e+19
# 499973    1.311030e+17
# 499974    1.311030e+19
# 499975    1.311032e+19
# 499976    1.311037e+19
# 499977    1.311040e+18
# 499978    1.311044e+19
# ...

# %%
g1 = pd.Series(t0.id).groupby(group_by)
agg1  = g1.aggregate(np.size)
#print agg1

# %%
agg1
# Out:
# 00001c3b     2.0
# 00009aad     1.0
# 0000bfc0     2.0
# 0000c448     1.0
# 0000c90e     1.0
# 0001095d     6.0
# 00011a60     1.0
# 0001488a     1.0
# 00014c42     4.0
# 00017d37     1.0
# 00018aa7     2.0
# 0001e083     1.0
# 0002133a     5.0
# 0002b40a     3.0
# 0002e212     1.0
# 0002f7e4     2.0
# 0003a4fa     1.0
# 0003ba91     1.0
# 00051d30     1.0
# 00053efb     1.0
# 000556c1     1.0
# 0005c284     1.0
# 0005cd34     2.0
# 00061507     1.0
# 00064509     1.0
# 000700cd     3.0
# 00073f28     2.0
# 0007786f    11.0
# 00086300     1.0
# 00099deb     1.0
#             ...
# fff5e653     1.0
# fff5e874     5.0
# fff63db3     6.0
# fff65f28     1.0
# fff66839    38.0
# fff681f0     1.0
# fff6e255     1.0
# fff71c98     3.0
# fff81b9e     1.0
# fff81f4b     4.0
# fff82817     1.0
# fff84cb1     1.0
# fff91977     1.0
# fff9d9bd     1.0
# fffa9147     1.0
# fffb099d     2.0
# fffbb7e7     1.0
# fffc40f7     1.0
# fffc6570     1.0
# fffc729b     1.0
# fffce275     1.0
# ...

# %%
r1 = agg1[group_by].values
r1
# Out:
# array([1412,    7,    2, ...,    1,    2,   18], dtype=int64)

# %%
g1 = pd.Series(t0.device_ip).groupby(group_by)
agg1  = g1.aggregate(np.size)
agg1
# Out:
# 00001c3b     2
# 00009aad     1
# 0000bfc0     2
# 0000c448     1
# 0000c90e     1
# 0001095d     6
# 00011a60     1
# 0001488a     1
# 00014c42     4
# 00017d37     1
# 00018aa7     2
# 0001e083     1
# 0002133a     5
# 0002b40a     3
# 0002e212     1
# 0002f7e4     2
# 0003a4fa     1
# 0003ba91     1
# 00051d30     1
# 00053efb     1
# 000556c1     1
# 0005c284     1
# 0005cd34     2
# 00061507     1
# 00064509     1
# 000700cd     3
# 00073f28     2
# 0007786f    11
# 00086300     1
# 00099deb     1
#             ..
# fff5e653     1
# fff5e874     5
# fff63db3     6
# fff65f28     1
# fff66839    38
# fff681f0     1
# fff6e255     1
# fff71c98     3
# fff81b9e     1
# fff81f4b     4
# fff82817     1
# fff84cb1     1
# fff91977     1
# fff9d9bd     1
# fffa9147     1
# fffb099d     2
# fffbb7e7     1
# fffc40f7     1
# fffc6570     1
# fffc729b     1
# fffce275     1
# fffceb4d     1
# fffd8c93     1
# fffdac0f     2
# fffe2401    11
# fffe4c19     2
# ffff354b     1
# ...

# %%
r1[0]
# Out:
# 1412.0

# %%
agg1['ddd2926e']
# Out:
# 1412.0

# %%
np.minimum([900,500,10,200],400)
# Out:
# array([400, 400,  10, 200])

# %%
import pandas as pd
import numpy as np

# %%
feature_list_dict = {}
feature_list_name = 'tvexp3'
list_param = ['C1', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'banner_pos', 'device_type', 'device_conn_type']
feature_list_dict[feature_list_name] =list_param

# %%
t0[feature_list_dict[feature_list_name]].values
# Out:
# array([[ 1005, 15706,   320, ...,     0,     1,     2],
#        [ 1005, 15704,   320, ...,     0,     1,     0],
#        [ 1005, 15704,   320, ...,     0,     1,     0],
#        ...,
#        [ 1005, 20633,   320, ...,     0,     1,     0],
#        [ 1005, 20355,   216, ...,     1,     1,     0],
#        [ 1005,  6563,   320, ...,     0,     1,     0]], dtype=int64)

# %%
t0.as_matrix(feature_list_dict[feature_list_name])
# Out:
# C:\Users\shachuanyu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([[ 1005, 15706,   320, ...,     0,     1,     2],
#        [ 1005, 15704,   320, ...,     0,     1,     0],
#        [ 1005, 15704,   320, ...,     0,     1,     0],
#        ...,
#        [ 1005, 20633,   320, ...,     0,     1,     0],
#        [ 1005, 20355,   216, ...,     1,     1,     0],
#        [ 1005,  6563,   320, ...,     0,     1,     0]], dtype=int64)

# %%
dump(t0,"t0.joblib_dat")
# Out:
# ['t0.joblib_dat']

# %%
t1 = load("t0.joblib_dat")

# %%
t1
# Out:
#                   id  click      hour    C1  banner_pos   site_id site_domain  \
# 0       1.000009e+18      0  14102100  1005           0  1fbe01fe    f3845767
# 1       1.000017e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 2       1.000037e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 3       1.000064e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 4       1.000068e+19      0  14102100  1005           1  fe8cc448    9166c161
# 5       1.000072e+19      0  14102100  1005           0  d6137915    bb1ef334
# 6       1.000072e+19      0  14102100  1005           0  8fda644b    25d4cfcd
# 7       1.000092e+19      0  14102100  1005           1  e151e245    7e091613
# 8       1.000095e+19      1  14102100  1005           0  1fbe01fe    f3845767
# 9       1.000126e+19      0  14102100  1002           0  84c7ba46    c4e18dd6
# 10      1.000187e+19      0  14102100  1005           1  e151e245    7e091613
# ...

# %%
_cat = pd.Series(np.add(t0['app_domain'].values, t0['site_domain'].values)).astype('category').values.codes
_cat
# Out:
# array([1565, 1565, 1565, ...,   47,  175,  813], dtype=int16)

# %%
_cat+1
# Out:
# array([1566, 1566, 1566, ...,   48,  176,  814], dtype=int16)

# %%
_cat1 = np.asarray(_cat, dtype='int32')
_cat1
# Out:
# array([1565, 1565, 1565, ...,   47,  175,  813])

# %%
vns0 = ['app_or_web', 'banner_pos', 'C1', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21']
vns1 = vns0 + ['hour1'] + ['_A_' + vn for vn in vns0] + \
 ['device_model', 'device_type', 'device_conn_type', 'app_site_id', 'as_domain', 'as_category',
      'cnt_device_ip_day_hour', 'cnt_device_ip_day_hour_prev', 'cnt_device_ip_day_hour_next', 'cnt_device_ip_pday',
     'cnt_diff_device_ip_day_pday', 'as_model'] + \
    [ 'dev_id_cnt2', 'dev_ip_cnt2', 'C14', '_A_C14', 'dev_ip2plus', 'dev_id2plus']

# %%
vns1
# Out:
# ['app_or_web',
#  'banner_pos',
#  'C1',
#  'C15',
#  'C16',
#  'C17',
#  'C18',
#  'C19',
#  'C20',
#  'C21',
#  'hour1',
#  '_A_app_or_web',
#  '_A_banner_pos',
#  '_A_C1',
#  '_A_C15',
#  '_A_C16',
#  '_A_C17',
#  '_A_C18',
#  '_A_C19',
#  '_A_C20',
#  '_A_C21',
#  'device_model',
#  'device_type',
#  'device_conn_type',
#  'app_site_id',
#  'as_domain',
#  'as_category',
#  'cnt_device_ip_day_hour',
#  'cnt_device_ip_day_hour_prev',
#  'cnt_device_ip_day_hour_next',
#  'cnt_device_ip_pday',
#  'cnt_diff_device_ip_day_pday',
#  'as_model',
#  'dev_id_cnt2',
#  'dev_ip_cnt2',
#  'C14',
#  '_A_C14',
#  'dev_ip2plus',
#  'dev_id2plus']
